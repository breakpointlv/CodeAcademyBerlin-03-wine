# %%
import numpy as np
import pandas as pd
import seaborn as sns

red_color = 'red'
white_color = 'yellow'

palette_color = sns.color_palette('dark')
sns.set(rc={'figure.figsize':(25,15)})
#sns.set(font_scale=2)



red = pd.read_csv('winequality/winequality-red.csv', sep=";")
white = pd.read_csv('winequality/winequality-white.csv', sep=";")

# concat two data sets
red['type'] = 'red'
white['type'] = 'white'

w = pd.concat([red, white], ignore_index=True)

# %%
display(w.head(10))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
display(w.tail(10))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6487            6.8             0.220         0.36            1.20      0.052
# 6488            4.9             0.235         0.27           11.75      0.030
# 6489            6.1             0.340         0.29            2.20      0.036
# 6490            5.7             0.210         0.32            0.90      0.038
# 6491            6.5             0.230         0.38            1.30      0.032
# 6492            6.2             0.210         0.29            1.60      0.039
# 6493            6.6             0.320         0.36            8.00      0.047
# 6494            6.5             0.240         0.19            1.20      0.041
# 6495            5.5             0.290         0.30            1.10      0.022
# 6496            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  type                  6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
w.shape
# Out:
# (6497, 13)

# %%
display(w[w.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, type]
# Index: []

# %%
w.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
w['quality_label'] = w['quality'].apply(
    lambda value: 'low'
    if value <= 5 else 'medium'
    if value <= 7 else 'high'
)
w['quality_label'] = pd.Categorical(w['quality_label'], categories=['low', 'medium', 'high'])

# %%
red = w[w['type'] == 'red']
white = w[w['type'] == 'white']
display(red.describe().compare(white.describe()))
# Out:
#       fixed acidity              volatile acidity               citric acid  \
#                self        other             self        other         self
# count   1599.000000  4898.000000      1599.000000  4898.000000  1599.000000
# mean       8.319637     6.854788         0.527821     0.278241     0.270976
# std        1.741096     0.843868         0.179060     0.100795     0.194801
# min        4.600000     3.800000         0.120000     0.080000          NaN
# 25%        7.100000     6.300000         0.390000     0.210000     0.090000
# 50%        7.900000     6.800000         0.520000     0.260000     0.260000
# 75%        9.200000     7.300000         0.640000     0.320000     0.420000
# max       15.900000    14.200000         1.580000     1.100000     1.000000
#
#                    residual sugar                 chlorides               ...  \
#              other           self        other         self        other  ...
# ...

# %%
# red whines are more acidic mean 8.3 > 6.9
# white whine has les valatile acidity 0.52 > 0.27
# white wine has a lot more sugar 2.53 < 6.39 and max 15.5 < 65.8
# red whine has more calories 0.087 > 0.045

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('classic')

# %%
qual_label_counts = w['quality_label'].value_counts()
plt.pie(qual_label_counts, labels=qual_label_counts.index, colors=palette_color, autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=(30,30))

red_ql = red['quality_label'].value_counts()
white_ql = white['quality_label'].value_counts()

plt.subplot(1, 2, 1)
plt.title('Red')
plt.pie(red_ql, labels=red_ql.index, colors=palette_color, autopct='%.0f%%')

plt.subplot(1, 2, 2)
plt.title('White')
plt.pie(white_ql, labels=white_ql.index, colors=palette_color, autopct='%.0f%%')

plt.show()

# %%
fig, ax = plt.subplots(1, 2)


fig.suptitle('Wine quality')

ax[0].set_ylim(1, 3200)
ax[0].set_title('White wine')

ax[1].set_ylim(1, 3200)
ax[1].set_title('Red wine')

sns.histplot(data=white['quality_label'], ax=ax[0], color=white_color)
sns.histplot(data=red['quality_label'], ax=ax[1], color=red_color)
# Out:
# <AxesSubplot: title={'center': 'Red wine'}, xlabel='quality_label', ylabel='Count'>

# %%
fig, ax = plt.subplots(1, 2)

fig.suptitle('Wine quality')

ax[0].set_ylim(1, 16)
ax[0].set_title('White wine')

ax[1].set_ylim(1, 16)
ax[1].set_title('Red wine')

sns.boxplot(y=red['alcohol'], x=red['quality_label'], ax=ax[0])
sns.boxplot(y=white['alcohol'], x=white['quality_label'], ax=ax[1])
# Out:
# <AxesSubplot: title={'center': 'Red wine'}, xlabel='quality_label', ylabel='alcohol'>

# %%
sns.set(rc={'figure.figsize':(25,15)})

sns.lineplot(
    x=w['fixed acidity'],
    y=w['volatile acidity']
)
# Out:
# <AxesSubplot: xlabel='fixed acidity', ylabel='volatile acidity'>

# %%
sns.countplot(x='quality', data=w).set(title='Wine count by quality')
# Out:
# [Text(0.5, 1.0, 'Wine count by quality')]

# %%
sns.barplot(x=w['total sulfur dioxide'], y=w['free sulfur dioxide']).title('total vs free sulfur dioxide')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.barplot(x=w['total sulfur dioxide'], y=w['free sulfur dioxide']).title('total vs free sulfur dioxide')
#
# TypeError: 'Text' object is not callable

# %%
sns.barplot(x=w['total sulfur dioxide'], y=w['total sulfur dioxide']/w['free sulfur dioxide']).title('total vs free sulfur dioxide')

# %%
sns.pairplot(w, hue='quality')

# %%
sns.displot(x=w['residual sugar'], y=w['alcohol'])

# %%
white.hist(bins=15, color=white_color, edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
red.hist(bins=15, color=red_color, edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
fig, ax = plt.subplots(1, 2)

fig.suptitle('Residual sugar')

x_max =  max(w['residual sugar'])
ax[0].set_ylim(1, 1000)
ax[0].set_xlim(1, x_max)
ax[0].set_title('White wine')

ax[1].set_ylim(1, 1000)
ax[1].set_xlim(1, x_max)
ax[1].set_title('Red wine')

sns.histplot(red['residual sugar'], ax=ax[0], color=red_color)
sns.histplot(white['residual sugar'], ax=ax[1], color=white_color)

# %%
wine_corr = w.corr(numeric_only=True)
wine_corr = wine_corr.mask(np.triu(np.ones(wine_corr.shape)).astype('bool'))

sns.heatmap(
    wine_corr,
    cmap='RdBu_r',
    vmin=-1, vmax=1,
    annot=True, annot_kws={'fontsize':16, 'fontweight':'bold'}
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 wine_corr = w.corr(numeric_only=True)
#       2 wine_corr = wine_corr.mask(np.triu(np.ones(wine_corr.shape)).astype('bool'))
#       4 sns.heatmap(
#       5     wine_corr,
#       6     cmap='RdBu_r',
#       7     vmin=-1, vmax=1,
#       8     annot=True, annot_kws={'fontsize':16, 'fontweight':'bold'}
#       9 )
#
# NameError: name 'w' is not defined

# %%
sns.jointplot(x=w['quality'], y=w['alcohol']).set(title='Wine quality and alcohol')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = w['quality']
y = w['alcohol']
z = w['residual sugar']

ax.set_xlabel("Quality")
ax.set_ylabel("Alcohol")
ax.set_zlabel("Residual Sugar")

ax.scatter(x, y, z)

plt.show()

# %%
from scipy import stats

F, p = stats.f_oneway(
    red[red['quality_label'] == 'low']['alcohol'],
    red[red['quality_label'] == 'medium']['alcohol'],
    red[red['quality_label'] == 'high']['alcohol']
)
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('Red: F Statistic:', F, '\tp-value:', round(p, 8))

F, p = stats.f_oneway(
    white[white['quality_label'] == 'low']['alcohol'],
    white[white['quality_label'] == 'medium']['alcohol'],
    white[white['quality_label'] == 'high']['alcohol']
)
print('White: F Statistic:', F, '\tp-value:', round(p, 8))

# %%
from scipy import stats

F, p = stats.f_oneway(
    red[red['quality_label'] == 'low']['chlorides'],
    red[red['quality_label'] == 'medium']['chlorides']
)
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('Red: F Statistic:', F, '\tp-value:', round(p,3))
